# %%
#https://www.kaggle.com/code/tanyildizderya/airline-passenger-lstm

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from statsmodels.tsa.stattools import adfuller

from sktime.transformations.series.adapt import PandasTransformAdaptor
from sktime.utils import plotting
from sktime.forecasting.theta import ThetaForecaster
from sktime.forecasting.exp_smoothing import ExponentialSmoothing
from sktime.performance_metrics.forecasting import mean_squared_error
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
from sktime.forecasting.croston import Croston
from sktime.datasets import load_PBS_dataset
from sktime.forecasting.arima import AutoARIMA
from sktime.datatypes import get_examples
from sktime.datatypes import check_raise
from sktime.datasets import load_airline
from sktime.utils.plotting import plot_series
from sktime.transformations.series.difference import Differencer
from sktime.transformations.compose import InvertTransform
from sktime.forecasting.compose import TransformedTargetForecaster
from sktime.transformations.series.detrend import Deseasonalizer
from sktime.forecasting.trend import PolynomialTrendForecaster
from sktime.transformations.series.detrend import Detrender
from sktime.forecasting.compose import ForecastingPipeline
from sktime.transformations.series.boxcox import LogTransformer
from sktime.transformations.series.acf import AutoCorrelationTransformer
from sktime.transformations.series.impute import Imputer
from sktime.forecasting.model_selection import ExpandingWindowSplitter
from sktime.forecasting.model_selection import ForecastingGridSearchCV
from statsmodels.tsa.stattools import adfuller
from sktime.transformations.series.boxcox import BoxCoxTransformer
from sktime.performance_metrics.forecasting import MeanAbsolutePercentageError
from sktime.transformations.compose import TransformerPipeline
from sktime.transformations.series.adapt import TabularToSeriesAdaptor
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

tf.keras.backend.clear_session()
tf.compat.v1.disable_eager_execution() #IF ERROR, UNCOMMENT
# Any results you write to the current directory are saved as output.

patience = 25
sp = 12
timestamp= 10

# %%
df = pd.read_csv('AirPassengers.csv',parse_dates=['Month'])
# productNumber = "12141"
# datasetTarget="/home/esteban/Documents/Optimix/DeepAR/tools/correctedsupplyProduct_"+productNumber+".csv"
# df = pd.read_csv(datasetTarget, header=0, index_col=0)
# df.reset_index(inplace=True)
# df.head()

# %%
dataset = df.iloc[:,1].values
plt.plot(dataset)
plt.xlabel('time')
plt.ylabel('number of passengers')
plt.title('Internatoinal Airline Passenger')
plt.show()

# %%
dataset = dataset.reshape(-1,1)
dataset = dataset.astype('float32')
dataset.shape
test = dataset.reshape(1,-1)[0][78:]
# print(test)

# %%
usePipe = True

if (usePipe):
    pipe = TransformerPipeline(steps=[
            ("imputer", Imputer(method="mean")),
            ("boxcox", BoxCoxTransformer()),
            ("minmaxscaler", TabularToSeriesAdaptor(MinMaxScaler())),
#             ("deseasonalize", Deseasonalizer(model="additive", sp=sp)),
#             ("detrend", Detrender(forecaster=PolynomialTrendForecaster(degree=2))),
#             ("differencer", Differencer(lags=1, na_handling='fill_zero')),
    #         ("differencer", Differencer(lags=12, na_handling='fill_zero')),
    #     ("forecaster", NaiveForecaster(strategy="drift")),
    ])
    dataset = pipe.fit_transform(dataset)
    
else:
    scaler = MinMaxScaler(feature_range=(0,1))
    dataset = scaler.fit_transform(dataset)

#Is scaling train + test dataset introducing bias ?

# %%
train_size = int(len(dataset)*0.50)
test_size = len(dataset) - train_size
train = dataset[:train_size,:]
test = dataset[train_size:len(dataset),:]
print('train_size : {}, test_size : {}, total_size : {}'.format(len(train),len(test),len(dataset)))
# Out:
# train_size : 72, test_size : 72, total_size : 144

# %%
dataX = []
dataY = []
for i in range(len(train)-timestamp-1):
    a = train[i:(i+timestamp),0]
    dataX.append(a)
    dataY.append(train[i+timestamp,0])
trainX = np.array(dataX)
trainY = np.array(dataY)

dataX = []
dataY = []
for i in range(len(test)-timestamp-1):
    a = test[i:(i+timestamp),0]
    dataX.append(a)
    dataY.append(test[i+timestamp,0])
testX = np.array(dataX)
testY = np.array(dataY)

# print(testX, testY)

# %%
trainX = np.reshape(trainX,(trainX.shape[0],1,trainX.shape[1])) #(number of points, features number, lookback)
testX = np.reshape(testX,(testX.shape[0],1,testX.shape[1]))

print('trainX shape : {}, testX shape : {}'.format(trainX.shape,testX.shape))
print('trainY shape : {}, testY shape : {}'.format(trainY.shape,testY.shape))
#X shape (number of points, number of features, lookback)
#Y shape (number of points, 1)
# Out:
# trainX shape : (61, 1, 10), testX shape : (61, 1, 10)
# trainY shape : (61,), testY shape : (61,)

# %%
# model
model = Sequential()
model.add(Dense(32))
# model.add(LSTM(32, input_shape=(1, timestamp))) # 10 lstm neuron(block)
model.add(LSTM(32)) # 10 lstm neuron(block)
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate=5e-5)) #'adam'
# history = model.fit(trainX, trainY, epochs=50, batch_size=1)
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=patience, monitor="val_loss",min_delta=0.0001)
]
history = model.fit(trainX, trainY, epochs=500, batch_size=1, validation_data=(testX,testY), callbacks=callbacks)
tf.keras.utils.plot_model(model, show_shapes=True)
plt.title('model loss')
try :
    plt.plot(history.history['val_loss'])
    plt.ylabel('val_loss')
except : 
    plt.plot(history.history['loss'])
    plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Train on 61 samples, validate on 61 samples
# Epoch 1/500
# 58/61 [===========================>..] - ETA: 0s - loss: 0.0794
# /home/esteban/anaconda3/envs/Keras/lib/python3.10/site-packages/keras/engine/training_v1.py:2332: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 61/61 [==============================] - 1s 6ms/sample - loss: 0.0781 - val_loss: 0.3074
# Epoch 2/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0589 - val_loss: 0.2273
# Epoch 3/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0428 - val_loss: 0.1572
# Epoch 4/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0296 - val_loss: 0.1054
# Epoch 5/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0202 - val_loss: 0.0637
# Epoch 6/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0135 - val_loss: 0.0382
# Epoch 7/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0093 - val_loss: 0.0239
# Epoch 8/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0072 - val_loss: 0.0166
# Epoch 9/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0062 - val_loss: 0.0123
# Epoch 10/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0058 - val_loss: 0.0108
# Epoch 11/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0056 - val_loss: 0.0098
# Epoch 12/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0056 - val_loss: 0.0097
# Epoch 13/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0055 - val_loss: 0.0096
# Epoch 14/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0055 - val_loss: 0.0093
# Epoch 15/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0054 - val_loss: 0.0091
# Epoch 16/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0053 - val_loss: 0.0091
# Epoch 17/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0053 - val_loss: 0.0089
# Epoch 18/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0052 - val_loss: 0.0088
# Epoch 19/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0052 - val_loss: 0.0087
# Epoch 20/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0052 - val_loss: 0.0085
# Epoch 21/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0051 - val_loss: 0.0083
# Epoch 22/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0051 - val_loss: 0.0083
# Epoch 23/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0050 - val_loss: 0.0082
# Epoch 24/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0049 - val_loss: 0.0082
# Epoch 25/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0049 - val_loss: 0.0079
# Epoch 26/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0048 - val_loss: 0.0082
# Epoch 27/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0048 - val_loss: 0.0079
# Epoch 28/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0048 - val_loss: 0.0077
# Epoch 29/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0047 - val_loss: 0.0076
# Epoch 30/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0047 - val_loss: 0.0074
# Epoch 31/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0046 - val_loss: 0.0075
# Epoch 32/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0046 - val_loss: 0.0073
# Epoch 33/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0045 - val_loss: 0.0069
# Epoch 34/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0045 - val_loss: 0.0072
# Epoch 35/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0044 - val_loss: 0.0068
# Epoch 36/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0044 - val_loss: 0.0067
# Epoch 37/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0043 - val_loss: 0.0068
# Epoch 38/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0043 - val_loss: 0.0069
# Epoch 39/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0042 - val_loss: 0.0066
# Epoch 40/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0042 - val_loss: 0.0065
# Epoch 41/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0042 - val_loss: 0.0065
# Epoch 42/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0041 - val_loss: 0.0062
# Epoch 43/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0040 - val_loss: 0.0062
# Epoch 44/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0040 - val_loss: 0.0059
# Epoch 45/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0040 - val_loss: 0.0059
# Epoch 46/500
# 61/61 [==============================] - 0s 5ms/sample - loss: 0.0039 - val_loss: 0.0061
# Epoch 47/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0039 - val_loss: 0.0058
# Epoch 48/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0039 - val_loss: 0.0056
# Epoch 49/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0038 - val_loss: 0.0057
# Epoch 50/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0038 - val_loss: 0.0056
# Epoch 51/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0038 - val_loss: 0.0054
# Epoch 52/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0037 - val_loss: 0.0056
# Epoch 53/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0037 - val_loss: 0.0053
# Epoch 54/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0036 - val_loss: 0.0051
# Epoch 55/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0036 - val_loss: 0.0051
# Epoch 56/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0036 - val_loss: 0.0052
# Epoch 57/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0035 - val_loss: 0.0049
# Epoch 58/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0035 - val_loss: 0.0048
# Epoch 59/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0035 - val_loss: 0.0048
# Epoch 60/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0034 - val_loss: 0.0048
# Epoch 61/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0034 - val_loss: 0.0047
# Epoch 62/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0034 - val_loss: 0.0046
# Epoch 63/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0033 - val_loss: 0.0047
# Epoch 64/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0033 - val_loss: 0.0045
# Epoch 65/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0033 - val_loss: 0.0045
# Epoch 66/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0032 - val_loss: 0.0045
# Epoch 67/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0032 - val_loss: 0.0043
# Epoch 68/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0032 - val_loss: 0.0043
# Epoch 69/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0032 - val_loss: 0.0042
# Epoch 70/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0031 - val_loss: 0.0043
# Epoch 71/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0031 - val_loss: 0.0042
# Epoch 72/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0031 - val_loss: 0.0041
# Epoch 73/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0031 - val_loss: 0.0040
# Epoch 74/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0030 - val_loss: 0.0042
# Epoch 75/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0030 - val_loss: 0.0039
# Epoch 76/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0030 - val_loss: 0.0040
# Epoch 77/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0030 - val_loss: 0.0041
# Epoch 78/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0030 - val_loss: 0.0040
# Epoch 79/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0029 - val_loss: 0.0039
# Epoch 80/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0029 - val_loss: 0.0037
# Epoch 81/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0029 - val_loss: 0.0038
# Epoch 82/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0029 - val_loss: 0.0038
# Epoch 83/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0029 - val_loss: 0.0037
# Epoch 84/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0028 - val_loss: 0.0040
# Epoch 85/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0028 - val_loss: 0.0036
# Epoch 86/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0028 - val_loss: 0.0037
# Epoch 87/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0027 - val_loss: 0.0034
# Epoch 88/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0028 - val_loss: 0.0036
# Epoch 89/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0027 - val_loss: 0.0034
# Epoch 90/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0027 - val_loss: 0.0034
# Epoch 91/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0027 - val_loss: 0.0035
# Epoch 92/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0027 - val_loss: 0.0033
# Epoch 93/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0027 - val_loss: 0.0035
# Epoch 94/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0027 - val_loss: 0.0033
# Epoch 95/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0027 - val_loss: 0.0033
# Epoch 96/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0026 - val_loss: 0.0034
# Epoch 97/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0027 - val_loss: 0.0036
# Epoch 98/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0026 - val_loss: 0.0035
# Epoch 99/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0026 - val_loss: 0.0032
# Epoch 100/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0026 - val_loss: 0.0034
# Epoch 101/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0026 - val_loss: 0.0034
# Epoch 102/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0025 - val_loss: 0.0034
# Epoch 103/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0025 - val_loss: 0.0031
# Epoch 104/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0025 - val_loss: 0.0033
# Epoch 105/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0025 - val_loss: 0.0031
# Epoch 106/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0025 - val_loss: 0.0036
# Epoch 107/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0025 - val_loss: 0.0035
# Epoch 108/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0025 - val_loss: 0.0030
# Epoch 109/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0025 - val_loss: 0.0030
# Epoch 110/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0025 - val_loss: 0.0031
# Epoch 111/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0024 - val_loss: 0.0030
# Epoch 112/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0024 - val_loss: 0.0032
# Epoch 113/500
# 61/61 [==============================] - 0s 5ms/sample - loss: 0.0024 - val_loss: 0.0031
# Epoch 114/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0024 - val_loss: 0.0029
# Epoch 115/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0024 - val_loss: 0.0029
# Epoch 116/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0024 - val_loss: 0.0033
# Epoch 117/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0024 - val_loss: 0.0029
# Epoch 118/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0024 - val_loss: 0.0030
# Epoch 119/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0024 - val_loss: 0.0030
# Epoch 120/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0024 - val_loss: 0.0030
# Epoch 121/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0023 - val_loss: 0.0032
# Epoch 122/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0023 - val_loss: 0.0029
# Epoch 123/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0023 - val_loss: 0.0029
# Epoch 124/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0023 - val_loss: 0.0032
# Epoch 125/500
# 61/61 [==============================] - 0s 7ms/sample - loss: 0.0023 - val_loss: 0.0029
# Epoch 126/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0023 - val_loss: 0.0032
# Epoch 127/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0023 - val_loss: 0.0029
# Epoch 128/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0023 - val_loss: 0.0031
# Epoch 129/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0023 - val_loss: 0.0032
# Epoch 130/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0023 - val_loss: 0.0030
# Epoch 131/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0023 - val_loss: 0.0031
# Epoch 132/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0023 - val_loss: 0.0029
# Epoch 133/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0023 - val_loss: 0.0031
# Epoch 134/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0022 - val_loss: 0.0031
# Epoch 135/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0022 - val_loss: 0.0031
# Epoch 136/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0023 - val_loss: 0.0028
# Epoch 137/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0022 - val_loss: 0.0033
# Epoch 138/500
# 61/61 [==============================] - 0s 2ms/sample - loss: 0.0022 - val_loss: 0.0030
# Epoch 139/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0022 - val_loss: 0.0027
# Epoch 140/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0022 - val_loss: 0.0029
# Epoch 141/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0022 - val_loss: 0.0031
# Epoch 142/500
# 61/61 [==============================] - 0s 5ms/sample - loss: 0.0022 - val_loss: 0.0030
# Epoch 143/500
# 61/61 [==============================] - 0s 7ms/sample - loss: 0.0022 - val_loss: 0.0031
# Epoch 144/500
# 61/61 [==============================] - 0s 6ms/sample - loss: 0.0022 - val_loss: 0.0031
# Epoch 145/500
# 61/61 [==============================] - 0s 6ms/sample - loss: 0.0022 - val_loss: 0.0030
# Epoch 146/500
# 61/61 [==============================] - 0s 7ms/sample - loss: 0.0022 - val_loss: 0.0030
# Epoch 147/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0022 - val_loss: 0.0030
# Epoch 148/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0022 - val_loss: 0.0034
# Epoch 149/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0022 - val_loss: 0.0032
# Epoch 150/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0022 - val_loss: 0.0031
# Epoch 151/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0022 - val_loss: 0.0033
# Epoch 152/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0021 - val_loss: 0.0027
# Epoch 153/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0021 - val_loss: 0.0029
# Epoch 154/500
# 61/61 [==============================] - 0s 6ms/sample - loss: 0.0021 - val_loss: 0.0031
# Epoch 155/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0021 - val_loss: 0.0028
# Epoch 156/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0021 - val_loss: 0.0030
# Epoch 157/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0021 - val_loss: 0.0029
# Epoch 158/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0021 - val_loss: 0.0033
# Epoch 159/500
# 61/61 [==============================] - 0s 4ms/sample - loss: 0.0021 - val_loss: 0.0035
# Epoch 160/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0021 - val_loss: 0.0031
# Epoch 161/500
# 61/61 [==============================] - 0s 3ms/sample - loss: 0.0021 - val_loss: 0.0033

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# print(trainX.ravel())
print(trainX)
# print(trainPredict.ravel())
# print (testPredict)
if usePipe :
    trainPredict = pipe.inverse_transform(trainPredict)
#     print(trainPredict)
#     print(trainPredict.shape,np.array([trainY]).reshape(-1,1).shape)
#     print(np.array([trainY]).reshape(-1,1))
    trainY = pipe.inverse_transform(np.array([trainY]).reshape(-1,1))
#     print(trainY)
    testPredict = pipe.inverse_transform(testPredict)
    testY = pipe.inverse_transform(np.array([testY]).reshape(-1,1))

else :
    trainPredict = scaler.inverse_transform(trainPredict)
    trainY = scaler.inverse_transform([trainY])
    testPredict = scaler.inverse_transform(testPredict)
    testY = scaler.inverse_transform([testY])
# Out:
# [[[0.03639082 0.06225729 0.11850993 0.10689918 0.0747727  0.129898
#    0.17688361 0.17688361 0.13364612 0.06645891]]
#
#  [[0.06225729 0.11850993 0.10689918 0.0747727  0.129898   0.17688361
#    0.17688361 0.13364612 0.06645891 0.        ]]
#
#  [[0.11850993 0.10689918 0.0747727  0.129898   0.17688361 0.17688361
#    0.13364612 0.06645891 0.         0.06225729]]
#
#  [[0.10689918 0.0747727  0.129898   0.17688361 0.17688361 0.13364612
#    0.06645891 0.         0.06225729 0.0494678 ]]
#
#  [[0.0747727  0.129898   0.17688361 0.17688361 0.13364612 0.06645891
#    0.         0.06225729 0.0494678  0.09505606]]
#
#  [[0.129898   0.17688361 0.17688361 0.13364612 0.06645891 0.
#    0.06225729 0.0494678  0.09505606 0.15204183]]
#
#  [[0.17688361 0.17688361 0.13364612 0.06645891 0.         0.06225729
#    0.0494678  0.09505606 0.15204183 0.129898  ]]
#
#  [[0.17688361 0.13364612 0.06645891 0.         0.06225729 0.0494678
#    0.09505606 0.15204183 0.129898   0.09105495]]
#
#  [[0.13364612 0.06645891 0.         0.06225729 0.0494678  0.09505606
#    0.15204183 0.129898   0.09105495 0.1803503 ]]
#
#  [[0.06645891 0.         0.06225729 0.0494678  0.09505606 0.15204183
#    0.129898   0.09105495 0.1803503  0.24892896]]
#
#  [[0.         0.06225729 0.0494678  0.09505606 0.15204183 0.129898
#    0.09105495 0.1803503  0.24892896 0.24892896]]
#
#  [[0.06225729 0.0494678  0.09505606 0.15204183 0.129898   0.09105495
#    0.1803503  0.24892896 0.24892896 0.21068935]]
#
#  [[0.0494678  0.09505606 0.15204183 0.129898   0.09105495 0.1803503
#    0.24892896 0.24892896 0.21068935 0.12233024]]
#
#  [[0.09505606 0.15204183 0.129898   0.09105495 0.1803503  0.24892896
#    0.24892896 0.21068935 0.12233024 0.04514144]]
#
#  [[0.15204183 0.129898   0.09105495 0.1803503  0.24892896 0.24892896
#    0.21068935 0.12233024 0.04514144 0.14840765]]
#
#  [[0.129898   0.09105495 0.1803503  0.24892896 0.24892896 0.21068935
#    0.12233024 0.04514144 0.14840765 0.16636242]]
#
#  [[0.09105495 0.1803503  0.24892896 0.24892896 0.21068935 0.12233024
#    0.04514144 0.14840765 0.16636242 0.18379723]]
#
#  [[0.1803503  0.24892896 0.24892896 0.21068935 0.12233024 0.04514144
#    0.14840765 0.16636242 0.18379723 0.27316319]]
#
#  [[0.24892896 0.24892896 0.21068935 0.12233024 0.04514144 0.14840765
#    0.16636242 0.18379723 0.27316319 0.22691339]]
#
#  [[0.24892896 0.21068935 0.12233024 0.04514144 0.14840765 0.16636242
#    0.18379723 0.27316319 0.22691339 0.25507716]]
#
#  [[0.21068935 0.12233024 0.04514144 0.14840765 0.16636242 0.18379723
#    0.27316319 0.22691339 0.25507716 0.27316319]]
#
#  [[0.12233024 0.04514144 0.14840765 0.16636242 0.18379723 0.27316319
#    0.22691339 0.25507716 0.27316319 0.33262478]]
#
#  [[0.04514144 0.14840765 0.16636242 0.18379723 0.27316319 0.22691339
#    0.25507716 0.27316319 0.33262478 0.33262478]]
#
#  [[0.14840765 0.16636242 0.18379723 0.27316319 0.22691339 0.25507716
#    0.27316319 0.33262478 0.33262478 0.29073707]]
#
#  [[0.16636242 0.18379723 0.27316319 0.22691339 0.25507716 0.27316319
#    0.33262478 0.33262478 0.29073707 0.22370283]]
#
#  [[0.18379723 0.27316319 0.22691339 0.25507716 0.27316319 0.33262478
#    0.33262478 0.29073707 0.22370283 0.16988992]]
#
#  [[0.27316319 0.22691339 0.25507716 0.27316319 0.33262478 0.33262478
#    0.29073707 0.22370283 0.16988992 0.23644538]]
#
#  [[0.22691339 0.25507716 0.27316319 0.33262478 0.33262478 0.29073707
#    0.22370283 0.16988992 0.23644538 0.25201072]]
#
#  [[0.25507716 0.27316319 0.33262478 0.33262478 0.29073707 0.22370283
#    0.16988992 0.23644538 0.25201072 0.27907649]]
#
#  [[0.27316319 0.33262478 0.33262478 0.29073707 0.22370283 0.16988992
#    0.23644538 0.25201072 0.27907649 0.31620362]]
#
#  [[0.33262478 0.33262478 0.29073707 0.22370283 0.16988992 0.23644538
#    0.25201072 0.27907649 0.31620362 0.28201218]]
#
#  [[0.33262478 0.29073707 0.22370283 0.16988992 0.23644538 0.25201072
#    0.27907649 0.31620362 0.28201218 0.28784233]]
#
#  [[0.29073707 0.22370283 0.16988992 0.23644538 0.25201072 0.27907649
#    0.31620362 0.28201218 0.28784233 0.38198091]]
#
#  [[0.22370283 0.16988992 0.23644538 0.25201072 0.27907649 0.31620362
#    0.28201218 0.28784233 0.38198091 0.41129533]]
#
#  [[0.16988992 0.23644538 0.25201072 0.27907649 0.31620362 0.28201218
#    0.28784233 0.38198091 0.41129533 0.43933441]]
#
#  [[0.23644538 0.25201072 0.27907649 0.31620362 0.28201218 0.28784233
#    0.38198091 0.41129533 0.43933441 0.35907882]]
#
#  [[0.25201072 0.27907649 0.31620362 0.28201218 0.28784233 0.38198091
#    0.41129533 0.43933441 0.35907882 0.31063319]]
#
#  [[0.27907649 0.31620362 0.28201218 0.28784233 0.38198091 0.41129533
#    0.43933441 0.35907882 0.31063319 0.25507716]]
#
#  [[0.31620362 0.28201218 0.28784233 0.38198091 0.41129533 0.43933441
#    0.35907882 0.31063319 0.25507716 0.31897041]]
#
#  [[0.28201218 0.28784233 0.38198091 0.41129533 0.43933441 0.35907882
#    0.31063319 0.25507716 0.31897041 0.32446773]]
#
#  [[0.28784233 0.38198091 0.41129533 0.43933441 0.35907882 0.31063319
#    0.25507716 0.31897041 0.32446773 0.32446773]]
#
#  [[0.38198091 0.41129533 0.43933441 0.35907882 0.31063319 0.25507716
#    0.31897041 0.32446773 0.32446773 0.42546672]]
#
#  [[0.41129533 0.43933441 0.35907882 0.31063319 0.25507716 0.31897041
#    0.32446773 0.32446773 0.42546672 0.4231263 ]]
#
#  [[0.43933441 0.35907882 0.31063319 0.25507716 0.31897041 0.32446773
#    0.32446773 0.42546672 0.4231263  0.40890287]]
#
#  [[0.35907882 0.31063319 0.25507716 0.31897041 0.32446773 0.32446773
#    0.42546672 0.4231263  0.40890287 0.44161715]]
#
#  [[0.31063319 0.25507716 0.31897041 0.32446773 0.32446773 0.42546672
#    0.4231263  0.40890287 0.44161715 0.48779745]]
#
#  [[0.25507716 0.31897041 0.32446773 0.32446773 0.42546672 0.4231263
#    0.40890287 0.44161715 0.48779745 0.50456909]]
#
#  [[0.31897041 0.32446773 0.32446773 0.42546672 0.4231263  0.40890287
#    0.44161715 0.48779745 0.50456909 0.42779871]]
#
#  [[0.32446773 0.32446773 0.42546672 0.4231263  0.40890287 0.44161715
#    0.48779745 0.50456909 0.42779871 0.36423978]]
#
#  [[0.32446773 0.42546672 0.4231263  0.40890287 0.44161715 0.48779745
#    0.50456909 0.42779871 0.36423978 0.27907649]]
#
#  [[0.42546672 0.4231263  0.40890287 0.44161715 0.48779745 0.50456909
#    0.42779871 0.36423978 0.27907649 0.33800479]]
#
#  [[0.4231263  0.40890287 0.44161715 0.48779745 0.50456909 0.42779871
#    0.36423978 0.27907649 0.33800479 0.34598992]]
#
#  [[0.40890287 0.44161715 0.48779745 0.50456909 0.42779871 0.36423978
#    0.27907649 0.33800479 0.34598992 0.30218365]]
#
#  [[0.44161715 0.48779745 0.50456909 0.42779871 0.36423978 0.27907649
#    0.33800479 0.34598992 0.30218365 0.4231263 ]]
#
#  [[0.48779745 0.50456909 0.42779871 0.36423978 0.27907649 0.33800479
#    0.34598992 0.30218365 0.4231263  0.40409115]]
#
#  [[0.50456909 0.42779871 0.36423978 0.27907649 0.33800479 0.34598992
#    0.30218365 0.4231263  0.40409115 0.42077738]]
#
#  [[0.42779871 0.36423978 0.27907649 0.33800479 0.34598992 0.30218365
#    0.4231263  0.40409115 0.42077738 0.48779745]]
#
#  [[0.36423978 0.27907649 0.33800479 0.34598992 0.30218365 0.4231263
#    0.40409115 0.42077738 0.48779745 0.56393676]]
#
#  [[0.27907649 0.33800479 0.34598992 0.30218365 0.4231263  0.40409115
#    0.42077738 0.48779745 0.56393676 0.54667481]]
#
#  [[0.33800479 0.34598992 0.30218365 0.4231263  0.40409115 0.42077738
#    0.48779745 0.56393676 0.54667481 0.47709396]]
#
#  [[0.34598992 0.30218365 0.4231263  0.40409115 0.42077738 0.48779745
#    0.56393676 0.54667481 0.47709396 0.40890287]]]
# /home/esteban/anaconda3/envs/Keras/lib/python3.10/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
if usePipe:
#     print(trainY,trainPredict)
    trainScore = math.sqrt(mean_squared_error(trainY, trainPredict[:,0]))
    print('Train Score: %.2f RMSE' % (trainScore))
    testScore = math.sqrt(mean_squared_error(testY, testPredict[:,0]))
    print('Test Score: %.2f RMSE' % (testScore))
    trainScore2 = math.sqrt(mean_absolute_percentage_error(trainY, trainPredict[:,0]))
    print('Train Score: %.2f MAPE' % (trainScore2))
    testScore2 = math.sqrt(mean_absolute_percentage_error(testY, testPredict[:,0]))
    print('Test Score: %.2f MAPE' % (testScore2))
else:
    trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
    print('Train Score: %.2f RMSE' % (trainScore))
    testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
    print('Test Score: %.2f RMSE' % (testScore))
    trainScore2 = math.sqrt(mean_absolute_percentage_error(trainY[0], trainPredict[:,0]))
    print('Train Score: %.2f MAPE' % (trainScore2))
    testScore2 = math.sqrt(mean_absolute_percentage_error(testY[0], testPredict[:,0]))
    print('Test Score: %.2f MAPE' % (testScore2))
# Out:
# Train Score: 16.15 RMSE
# Test Score: 38.00 RMSE
# Train Score: 0.27 MAPE
# Test Score: 0.27 MAPE

# %%
trainPredictPlot = np.empty_like(dataset)
# print(trainPredictPlot)
trainPredictPlot[:, :] = np.nan
# print(trainPredictPlot)
trainPredictPlot[timestamp:len(trainPredict)+timestamp, :] = trainPredict
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(timestamp*2)+1:len(dataset)-1, :] = testPredict

# print(trainPredictPlot)
if usePipe:
    plt.plot(pipe.inverse_transform(dataset))
    plt.plot(trainPredictPlot)
    plt.plot(testPredictPlot)
    plt.show()
else:
    plt.plot(scaler.inverse_transform(dataset))
    plt.plot(trainPredictPlot)
    plt.plot(testPredictPlot)
    plt.show()

# %%
from keras2cpp import export_model
export_model(model, 'KerasTestModel.model')

# %%
# ADF Test
from statsmodels.tsa.stattools import adfuller

df = pd.read_csv('AirPassengers.csv',parse_dates=['Month'])
pipe = TransformerPipeline(steps=[
        ("imputer", Imputer(method="mean")),
        ("boxcox", BoxCoxTransformer()),
        ("minmaxscaler", TabularToSeriesAdaptor(MinMaxScaler())),
        ("deseasonalize", Deseasonalizer(model="additive", sp=sp)),
        ("detrend", Detrender(forecaster=PolynomialTrendForecaster(degree=2))),
#             ("differencer", Differencer(lags=1, na_handling='fill_zero')),
#         ("differencer", Differencer(lags=12, na_handling='fill_zero')),
#     ("forecaster", NaiveForecaster(strategy="drift")),
])
tdf = pipe.fit_transform(df["Passengers"])
result = adfuller(tdf, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')   
    
plt.title("Line graph")
plt.plot(df["Month"], tdf)
# plt.grid(which="both")
plt.show()
# Out:
# ADF Statistic: -3.0824733206804718
# n_lags: 0.027877724852991947
# p-value: 0.027877724852991947
# Critial Values:
#    1%, -3.4816817173418295
# Critial Values:
#    5%, -2.8840418343195267
# Critial Values:
#    10%, -2.578770059171598
